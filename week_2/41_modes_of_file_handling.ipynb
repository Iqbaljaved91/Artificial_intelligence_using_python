# %%
file1 = open("demo2.txt", "r")

# %%
print(file1.read())
# Out:
# This is a test.
# Newline!

# %%
file1.close()

# %%
file1 = open("demo2.txt", "w")

# %%
file1.write("This is another test.")
# Out:
# 21

# %%
file1.close()

# %%
file1 = open("demo2.text", "a")

# %%
file1.write("\nNew line added!")
# Out:
# 16

# %%
file1.close()
