# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\ali\appdata\local\programs\python\python313\lib\site-packages (2.5.1)
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import time

# %%
arr = np.array([[1,2,3], [4,5,6]])
print(arr.shape)   # (2, 3)
print(arr.shape)   # 2
print(arr.dtype)   # int64 (or platform dependent)
# Out:
# (2, 3)
# (2, 3)
# int64

# %%
py_list = list(range(1_000_000))
py_result = []
start_time = time.time()
for i in py_list:
    py_result.append(i+5)
end_time = time.time()
print("Python List Time:", end_time - start_time)
# Out:
# Python List Time: 0.1968851089477539

# %%
np_array = np.arange(1_000_000)
start_time = time.time()
np_result = np_array + 5
end_time = time.time()
print("NumPy Array Time:", end_time - start_time)
# Out:
# NumPy Array Time: 0.005028486251831055
