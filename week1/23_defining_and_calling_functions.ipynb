# %%
def greet():
    print("Hello, world!")
    
greet()
# Out:
# Hello, world!

# %%
greet()
# Out:
# Hello, world!

# %%
def greet(name):
    print("Hello,", name)
    
greet("Ali")
# Out:
# Hello, Ali

# %%
greet("Sara")
# Out:
# Hello, Sara
