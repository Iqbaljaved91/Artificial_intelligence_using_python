# %%
for char in "Python":
    print(char)
# Out:
# P
# y
# t
# h
# o
# n

# %%
count = 0
for char in "banana":
    if char == "a":
        count += 1
print(count)
# Out:
# 3

# %%
s = "PYTHON"
rev = ""
for ch in s:
    rev = ch + rev


print(rev)
# Out:
# NOHTYP
