# %%
age = "34"

# %%
print(age)
# Out:
# 34

# %%
type(age)
# Out:
# str

# %%
print(int(age)+1)
# Out:
# 35

# %%
age = input("Please write your age")

# %%
type(age)

# %%
myAge = int(age)

# %%
type(myAge)
