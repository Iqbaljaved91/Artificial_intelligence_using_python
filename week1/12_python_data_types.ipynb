# %% [markdown]
# # Integer

# %%
age = 25
print(age)
# Out:
# 25

# %% [markdown]
# # Float

# %%
score = 3.5
print(score)
type(score)
# Out:
# 3.5
# float

# %% [markdown]
# # Addition of a variable and a number

# %%
print(score+1)
# Out:
# 4.5

# %% [markdown]
# # Strings

# %%
name = "Ali Zafar"
print(name)
print(name + " is good.")
# Out:
# Ali Zafar
# Ali Zafar is good.

# %% [markdown]
# # Boolean

# %%
is_passed = True
print(is_passed)
# Out:
# True
