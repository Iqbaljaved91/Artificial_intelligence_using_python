# %%
temp = 40

# %%
if temp > 35:
    print ("It is hot weather")
else:
    print ("It is not hot weather")
# Out:
# It is hot weather

# %%
temp = int(input("Enter temperature:"))

# %%
type(temp)

# %%
if temp > 35:
    print ("It is hot weather")
else:
    print ("It is not hot weather")
